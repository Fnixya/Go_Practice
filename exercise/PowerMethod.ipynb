# %%
import numpy as np

def power_iteration(A, x, k):

    u = x / np.linalg.norm(x)  # normalize vector

    for j in range(k): # power step
        x = np.dot(A, u)
        u = x / np.linalg.norm(x)

        lam = np.dot(u.T, np.dot(A, u))  # Rayleigh quotient
        print(f"Iteration {j+1}:")
        print(f"lambda = {lam}, u^T = ",u.T)

    return lam, u

# %%
# Example usage:
A = np.array([[4, -1], [-2, 3]])
x = np.array([[1], [1]])
k = 100

lam, u = power_iteration(A, x, k)
# Out:
# Iteration 1:
# lambda = [[3.]], u^T =  [[0.9486833  0.31622777]]
# Iteration 2:
# lambda = [[4.69230769]], u^T =  [[ 0.96476382 -0.26311741]]
# Iteration 3:
# lambda = [[5.07570978]], u^T =  [[ 0.83477268 -0.55059475]]
# Iteration 4:
# lambda = [[5.05980948]], u^T =  [[ 0.76048085 -0.64936036]]
# Iteration 5:
# lambda = [[5.0281207]], u^T =  [[ 0.72870293 -0.68482994]]
# Iteration 6:
# lambda = [[5.01188001]], u^T =  [[ 0.71577696 -0.69832896]]
# Iteration 7:
# lambda = [[5.00485043]], u^T =  [[ 0.71057944 -0.70361698]]
# Iteration 8:
# lambda = [[5.00195575]], u^T =  [[ 0.70849655 -0.70571428]]
# Iteration 9:
# lambda = [[5.00078478]], u^T =  [[ 0.7076628  -0.70655033]]
# Iteration 10:
# lambda = [[5.00031431]], u^T =  [[ 0.70732921 -0.70688429]]
# Iteration 11:
# lambda = [[5.00012579]], u^T =  [[ 0.70719575 -0.7070178 ]]
# Iteration 12:
# lambda = [[5.00005032]], u^T =  [[ 0.70714237 -0.70707119]]
# Iteration 13:
# lambda = [[5.00002013]], u^T =  [[ 0.70712102 -0.70709255]]
# Iteration 14:
# lambda = [[5.00000805]], u^T =  [[ 0.70711248 -0.70710109]]
# Iteration 15:
# lambda = [[5.00000322]], u^T =  [[ 0.70710906 -0.7071045 ]]
# Iteration 16:
# lambda = [[5.00000129]], u^T =  [[ 0.70710769 -0.70710587]]
# Iteration 17:
# lambda = [[5.00000052]], u^T =  [[ 0.70710715 -0.70710642]]
# Iteration 18:
# lambda = [[5.00000021]], u^T =  [[ 0.70710693 -0.70710664]]
# Iteration 19:
# lambda = [[5.00000008]], u^T =  [[ 0.70710684 -0.70710672]]
# Iteration 20:
# lambda = [[5.00000003]], u^T =  [[ 0.7071068  -0.70710676]]
# Iteration 21:
# lambda = [[5.00000001]], u^T =  [[ 0.70710679 -0.70710677]]
# Iteration 22:
# lambda = [[5.00000001]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 23:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 24:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 25:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 26:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 27:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 28:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 29:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 30:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 31:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 32:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 33:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 34:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 35:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 36:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 37:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 38:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 39:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 40:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 41:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 42:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 43:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 44:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 45:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 46:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 47:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 48:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 49:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 50:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 51:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 52:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 53:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 54:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 55:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 56:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 57:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 58:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 59:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 60:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 61:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 62:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 63:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 64:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 65:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 66:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 67:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 68:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 69:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 70:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 71:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 72:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 73:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 74:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 75:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 76:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 77:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 78:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 79:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 80:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 81:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 82:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 83:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 84:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 85:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 86:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 87:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 88:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 89:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 90:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 91:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 92:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 93:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 94:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 95:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 96:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 97:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 98:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 99:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]
# Iteration 100:
# lambda = [[5.]], u^T =  [[ 0.70710678 -0.70710678]]

# %%
# Calculate the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

print("Eigenvalues:\n", eigenvalues)  # 1D array
print("Eigenvectors:\n", eigenvectors.T)  # Each row is an eigenvector
# Out:
# Eigenvalues:
#  [5. 2.]
# Eigenvectors:
#  [[ 0.70710678 -0.70710678]
#  [ 0.4472136   0.89442719]]

# %%
def power_iteration2(A, x, itmax, tol):

    u = x / np.linalg.norm(x)  # normalize vector
    lam = np.dot(u.T, np.dot(A, u))  # Rayleigh quotient
    dlam = 1
    lam0 = lam
    it = 1

    print(f'Iteration {it}: lambda = {lam}')

    while np.abs(dlam)>tol and it<itmax:
        x = np.dot(A, u)  # power step
        u = x / np.linalg.norm(x)

        lam = np.dot(u.T, np.dot(A, u))  # Rayleigh quotient
        dlam = lam-lam0
        lam0 = lam
        it += 1

        print(f'Iteration {it}: lambda = {lam}')

    return lam, u, it

# %%
tol = 1e-11
lam, u, it = power_iteration2(A, x, k, tol)
print("-" * 45)
print("Eigenvalue:", lam)
print("Eigenvector:", u)
print("Iterations:", it)
# Out:
# Iteration 1: lambda = [[2.]]
# Iteration 2: lambda = [[3.]]
# Iteration 3: lambda = [[4.69230769]]
# Iteration 4: lambda = [[5.07570978]]
# Iteration 5: lambda = [[5.05980948]]
# Iteration 6: lambda = [[5.0281207]]
# Iteration 7: lambda = [[5.01188001]]
# Iteration 8: lambda = [[5.00485043]]
# Iteration 9: lambda = [[5.00195575]]
# Iteration 10: lambda = [[5.00078478]]
# Iteration 11: lambda = [[5.00031431]]
# Iteration 12: lambda = [[5.00012579]]
# Iteration 13: lambda = [[5.00005032]]
# Iteration 14: lambda = [[5.00002013]]
# Iteration 15: lambda = [[5.00000805]]
# Iteration 16: lambda = [[5.00000322]]
# Iteration 17: lambda = [[5.00000129]]
# Iteration 18: lambda = [[5.00000052]]
# Iteration 19: lambda = [[5.00000021]]
# Iteration 20: lambda = [[5.00000008]]
# Iteration 21: lambda = [[5.00000003]]
# Iteration 22: lambda = [[5.00000001]]
# Iteration 23: lambda = [[5.00000001]]
# Iteration 24: lambda = [[5.]]
# Iteration 25: lambda = [[5.]]
# Iteration 26: lambda = [[5.]]
# Iteration 27: lambda = [[5.]]
# Iteration 28: lambda = [[5.]]
# Iteration 29: lambda = [[5.]]
# Iteration 30: lambda = [[5.]]
# Iteration 31: lambda = [[5.]]
# ---------------------------------------------
# Eigenvalue: [[5.]]
# Eigenvector: [[ 0.70710678]
#  [-0.70710678]]
# Iterations: 31
